# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
mpl.style.use('seaborn-deep')

# %% [markdown]
# ## Getting the data

# %% [markdown]
# Reading data with sentiment analysis

# %%
gw_sent=pd.read_csv('data/sentiment_analysis/global_warming_sent.csv',index_col='Unnamed: 0')
ab_sent=pd.read_csv('data/sentiment_analysis/abortion_sent.csv',index_col='Unnamed: 0')
gi_sent=pd.read_csv('data/sentiment_analysis/gender_inequality_sent.csv',index_col='Unnamed: 0')
gc_sent=pd.read_csv('data/sentiment_analysis/gun_control_sent.csv',index_col='Unnamed: 0')

# %%
# Adding year column
gw_sent['year']=gw_sent['date'].apply(lambda x: x.split('-')[0])
ab_sent['year']=ab_sent['date'].apply(lambda x: x.split('-')[0])
gi_sent['year']=gi_sent['date'].apply(lambda x: x.split('-')[0])
gc_sent['year']=gc_sent['date'].apply(lambda x: x.split('-')[0])

# %% [markdown]
# Reading data with speakers attributes

# %%
gw=pd.read_csv('data/attributes/global_warming.csv',index_col='Unnamed: 0')
ab=pd.read_csv('data/attributes/abortion.csv',index_col='Unnamed: 0')
gi_sent=pd.read_csv('data/sentiment_analysis/gender_inequality_sent.csv',index_col='Unnamed: 0')
gc_sent=pd.read_csv('data/sentiment_analysis/gun_control_sent.csv',index_col='Unnamed: 0')

# %% [markdown]
# ## Analysis over the data

# %% [markdown]
# ### Global warming

# %%
gw_sent.head()
# Out:
#                       quoteID  \
# Unnamed: 0
# 321         2018-08-09-003074
# 828         2018-10-18-010126
# 936         2018-11-30-010680
# 1248        2018-05-22-013756
# 1395        2018-09-15-007731
#
#                                                     quotation  \
# Unnamed: 0
# 321         After growing up in a log cabin in the Mission...
# 828         As the UK heads towards an important new chapt...
# 936         Basically since widespread catchment deforesta...
# 1248        But there's still reason for optimism: We are ...
# 1395        Challenges to Both Left and Right in U.S. on G...
#
#                     speaker  \
# Unnamed: 0
# 321          Landon Gardner
# 828         Stewart Wingate
# 936                    None
# 1248          Michael Kelly
# 1395          Andrew Revkin
#
#                                                          qids  \
# Unnamed: 0
# 321                                             ['Q11752789']
# 828                                             ['Q23463543']
# 936                                                        []
# 1248        ['Q1385380', 'Q20811110', 'Q21458877', 'Q28824...
# 1395                                             ['Q4758379']
#
#                            date  \
# Unnamed: 0
# 321         2018-08-09 20:50:00
# 828         2018-10-18 16:34:49
# 936         2018-11-30 16:00:00
# 1248        2018-05-22 11:00:00
# 1395        2018-09-15 04:00:00
#
#                                                        probas  \
# Unnamed: 0
# 321         [['Landon Gardner', '0.7438'], ['None', '0.256...
# 828         [['Stewart Wingate', '0.9579'], ['None', '0.04...
# 936            [['None', '0.9151'], ['Dave Allen', '0.0849']]
# 1248        [['Michael Kelly', '0.9554'], ['None', '0.0446']]
# 1395        [['Andrew Revkin', '0.8461'], ['None', '0.1539']]
#
#             positive scores  negative scores  compound scores  year
# Unnamed: 0
# 321                   0.158              0.0           0.7650  2018
# 828                   0.096              0.0           0.1901  2018
# 936                   0.000              0.0           0.0000  2018
# 1248                  0.150              0.0           0.6956  2018
# 1395                  0.244              0.0           0.2263  2018

# %%
# Plotting Positive and Negative Probability Distributions

fig = plt.figure(figsize=(7,4))

ax = fig.add_subplot(1, 1, 1)

plt.hist(gw_sent['positive scores'],label='positive', bins = 50, alpha=0.9)
plt.hist(gw_sent['negative scores'],label='negative', bins = 50, alpha=0.6)
plt.xlabel('Probability',fontsize = 16)
plt.ylabel('Number of quotes',fontsize = 16)
plt.xlim([-0.005,1])
plt.title('Sentimental probability distributions for global warming', fontsize = 16)
plt.grid()
ax.set_yscale('log')

# this controls where you put the legend with bbox_to_anchor
plt.figlegend(ncol = 1,loc = 1, fontsize = 16, bbox_to_anchor=(0.4, 0.4, 0.5, 0.5))

# this controls the grid labels size
plt.tick_params(axis='both', which='major', labelsize=16)

# this makes the plot tight
plt.tight_layout()


None

# %%
# Plotting the Compound Scores

mpl.style.use('seaborn-deep')

fig = plt.figure(figsize=(7,4))

ax = fig.add_subplot(1, 1, 1)

plt.hist(gw_sent['compound scores'], bins = 70, alpha=0.9)
plt.xlabel('Compound score',fontsize = 16)
plt.ylabel('Number of quotes',fontsize = 16)
plt.xlim([-1.005,1.005])
plt.title('Distribution of compound score values for global warming', fontsize = 16)
plt.grid()
ax.set_yscale('log')

# this controls the grid labels size
plt.tick_params(axis='both', which='major', labelsize=16)

# this makes the plot tight
plt.tight_layout()

None

# %%
positive=gw_sent[gw_sent['compound scores']>=0.05]
negative=gw_sent[gw_sent['compound scores']<=-0.05]
neutral=gw_sent[np.abs(gw_sent['compound scores']) < 0.05]

# %%
neutral.describe()
# Out:
#        positive scores  negative scores  compound scores
# count     26380.000000     26380.000000     26380.000000
# mean          0.010279         0.009411         0.000332
# std           0.033114         0.031387         0.008413
# min           0.000000         0.000000        -0.049800
# 25%           0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000
# 75%           0.000000         0.000000         0.000000
# max           0.388000         0.324000         0.049800

# %%
positive.describe()
# Out:
#        positive scores  negative scores  compound scores
# count    110164.000000    110164.000000    110164.000000
# mean          0.185977         0.018335         0.601341
# std           0.095838         0.034598         0.258020
# min           0.014000         0.000000         0.050000
# 25%           0.114000         0.000000         0.381800
# 50%           0.171000         0.000000         0.636900
# 75%           0.241000         0.029000         0.831600
# max           0.884000         0.343000         0.998800

# %%
negative.describe()
# Out:
#        positive scores  negative scores  compound scores
# count     29821.000000     29821.000000     29821.000000
# mean          0.042987         0.146590        -0.423574
# std           0.050780         0.081922         0.236398
# min           0.000000         0.012000        -0.998500
# 25%           0.000000         0.088000        -0.599400
# 50%           0.031000         0.129000        -0.381800
# 75%           0.075000         0.185000        -0.249800
# max           0.419000         0.770000        -0.050000

# %%
# print total number of positive, negative and neutral quotes
print('Number of positive sent: ', positive.shape[0], '(', positive.shape[0]*100/gw_sent.shape[0],'%)')
print('Number of negative sent: ', negative.shape[0], '(', negative.shape[0]*100/gw_sent.shape[0],'%)')
print('Number of neutral sent: ', neutral.shape[0], '(', neutral.shape[0]*100/gw_sent.shape[0],'%)')
# Out:
# Number of positive sent:  110164 ( 66.21825504162534 %)
# Number of negative sent:  29821 ( 17.925044330237732 %)
# Number of neutral sent:  26380 ( 15.856700628136927 %)

# %%
#TODO: Compare positive,neutral,negative by vizualization

# %% [markdown]
# ### Abortion

# %%
ab_sent.head()
# Out:
#                       quoteID  \
# Unnamed: 0
# 1400011     2015-12-09-139783
# 1401214     2015-09-04-095700
# 1404392     2015-05-13-068629
# 1406420     2015-01-09-091216
# 1409432     2015-09-23-016630
#
#                                                     quotation  \
# Unnamed: 0
# 1400011     will push for energy development, beefed-up la...
# 1401214     The revered Mother Teresa, who works in the st...
# 1404392     We got done and she was standing on her head i...
# 1406420     while African Americans make up just 13 percen...
# 1409432     Conservatives worry about the way he seems to ...
#
#                         speaker                      qids  \
# Unnamed: 0
# 1400011     Victor Davis Hanson              ['Q1276395']
# 1401214                    None                        []
# 1404392           Dennis Rodman               ['Q201608']
# 1406420                    None                        []
# 1409432            Robert Royal  ['Q7349412', 'Q7349413']
#
#                            date  \
# Unnamed: 0
# 1400011     2015-12-09 06:33:51
# 1401214     2015-09-04 21:09:20
# 1404392     2015-05-13 16:50:41
# 1406420     2015-01-09 23:38:13
# 1409432     2015-09-23 16:35:22
#
#                                                        probas  \
# Unnamed: 0
# 1400011     [['Victor Davis Hanson', '0.7887'], ['None', '...
# 1401214     [['None', '0.8472'], ['Al Gore', '0.0952'], ['...
# 1404392     [['Dennis Rodman', '0.6836'], ['Carmen Electra...
# 1406420       [['None', '0.9263'], ['Alveda King', '0.0737']]
# 1409432     [['Robert Royal', '0.8235'], ['None', '0.1318'...
#
#             positive scores  negative scores  compound scores  year
# Unnamed: 0
# 1400011               0.064            0.104          -0.5719  2015
# 1401214               0.169            0.065           0.8350  2015
# 1404392               0.124            0.000           0.6249  2015
# 1406420               0.000            0.000           0.0000  2015
# 1409432               0.092            0.249          -0.6486  2015

# %%
# Plotting Positive and Negative Probability Distributions
mpl.style.use('seaborn-deep')

fig = plt.figure(figsize=(7,4))

ax = fig.add_subplot(1, 1, 1)

plt.hist(ab_sent['positive scores'],label='positive', bins = 50, alpha=0.9)
plt.hist(ab_sent['negative scores'],label='negative', bins = 50, alpha=0.6)
plt.xlabel('Probability',fontsize = 16)
plt.ylabel('Number of quotes',fontsize = 16)
plt.xlim([-0.005,1])
plt.title('Sentimental probability distributions for abortion', fontsize = 16)
plt.grid()
ax.set_yscale('log')

# this controls where you put the legend with bbox_to_anchor
plt.figlegend(ncol = 1,loc = 1, fontsize = 16, bbox_to_anchor=(0.4, 0.4, 0.5, 0.5))

# this controls the grid labels size
plt.tick_params(axis='both', which='major', labelsize=16)

# this makes the plot tight
plt.tight_layout()


None

# %%
# Plotting the Compound Scores

mpl.style.use('seaborn-deep')

fig = plt.figure(figsize=(7,4))

ax = fig.add_subplot(1, 1, 1)

plt.hist(ab_sent['compound scores'], bins = 70, alpha=0.9)
plt.xlabel('Compound score',fontsize = 16)
plt.ylabel('Number of quotes',fontsize = 16)
plt.xlim([-1.005,1.005])
plt.title('Distribution of compound score values for abortion', fontsize = 16)
plt.grid()
ax.set_yscale('log')

# this controls the grid labels size
plt.tick_params(axis='both', which='major', labelsize=16)

# this makes the plot tight
plt.tight_layout()

None

# %%
positive=ab_sent[ab_sent['compound scores']>=0.05]
negative=ab_sent[ab_sent['compound scores']<=-0.05]
neutral=ab_sent[np.abs(ab_sent['compound scores'])< 0.05]

# %%
neutral.describe()
# Out:
#        positive scores  negative scores  compound scores
# count      6801.000000      6801.000000      6801.000000
# mean          0.010469         0.009852         0.000155
# std           0.035739         0.034280         0.008437
# min           0.000000         0.000000        -0.049800
# 25%           0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000
# 75%           0.000000         0.000000         0.000000
# max           0.358000         0.344000         0.049800

# %%
positive.describe()
# Out:
#        positive scores  negative scores  compound scores
# count     14568.000000     14568.000000     14568.000000
# mean          0.169490         0.031016         0.519866
# std           0.091705         0.045643         0.249167
# min           0.013000         0.000000         0.050000
# 25%           0.103750         0.000000         0.328375
# 50%           0.153000         0.000000         0.510600
# 75%           0.216000         0.058000         0.726900
# max           0.778000         0.413000         0.996900

# %%
negative.describe()
# Out:
#        positive scores  negative scores  compound scores
# count     10997.000000     10997.000000     10997.000000
# mean          0.041669         0.178907        -0.507684
# std           0.052215         0.100372         0.251306
# min           0.000000         0.012000        -0.998700
# 25%           0.000000         0.107000        -0.718400
# 50%           0.000000         0.158000        -0.497600
# 75%           0.075000         0.227000        -0.296000
# max           0.338000         0.902000        -0.050700

# %%
# print total number of positive, negative and neutral quotes
print('Number of positive sent: ', positive.shape[0], '(', positive.shape[0]*100/ab_sent.shape[0],'%)')
print('Number of negative sent: ', negative.shape[0], '(', negative.shape[0]*100/ab_sent.shape[0],'%)')
print('Number of neutral sent: ', neutral.shape[0], '(', neutral.shape[0]*100/ab_sent.shape[0],'%)')
# Out:
# Number of positive sent:  14568 ( 45.01019588457023 %)
# Number of negative sent:  10997 ( 33.977012914787124 %)
# Number of neutral sent:  6801 ( 21.01279120064265 %)

# %% [markdown]
# ### Gender Inequality

# %%
gi_sent.head()
# Out:
#                       quoteID  \
# Unnamed: 0
# 3900322     2019-08-12-051728
# 3900920     2019-01-23-074654
# 3902699     2019-12-19-020869
# 3904083     2019-03-28-032705
# 3904546     2019-01-25-095509
#
#                                                     quotation  \
# Unnamed: 0
# 3900322     Not only winning the World Cup with her amazin...
# 3900920         Our main mission is to breach the gender gap,
# 3902699     Growing up in Pakistan, I was a feminist befor...
# 3904083     I didn't think I was breaking a trade secret, ...
# 3904546         The thing about misogyny is everyone does it,
#
#                        speaker          qids                 date  \
# Unnamed: 0
# 3900322           Taylor Swift    ['Q26876']  2019-08-12 12:55:41
# 3900920                   None            []  2019-01-23 05:46:04
# 3902699     Ziauddin Yousafzai  ['Q8071389']  2019-12-19 17:03:35
# 3904083           Piers Morgan   ['Q557758']  2019-03-28 04:09:36
# 3904546                   None            []  2019-01-25 21:18:53
#
#                                                        probas  \
# Unnamed: 0
# 3900322     [['Taylor Swift', '0.9038'], ['None', '0.0799'...
# 3900920         [['None', '0.9186'], ['Chang Liu', '0.0814']]
# 3902699     [['Ziauddin Yousafzai', '0.7561'], ['None', '0...
# 3904083     [['Piers Morgan', '0.8436'], ['None', '0.1361'...
# 3904546     [['None', '0.8255'], ['Karen Carpenter', '0.11...
#
#             positive scores  negative scores  compound scores  year
# Unnamed: 0
# 3900322               0.177            0.088           0.6717  2019
# 3900920               0.000            0.000           0.0000  2019
# 3902699               0.149            0.070           0.2144  2019
# 3904083               0.000            0.000           0.0000  2019
# 3904546               0.000            0.000           0.0000  2019

# %%
# Plotting Positive and Negative Probability Distributions
mpl.style.use('seaborn-deep')

fig = plt.figure(figsize=(7,4))

ax = fig.add_subplot(1, 1, 1)

plt.hist(gi_sent['positive scores'],label='positive', bins = 50, alpha=0.9)
plt.hist(gi_sent['negative scores'],label='negative', bins = 50, alpha=0.6)
plt.xlabel('Probability',fontsize = 16)
plt.ylabel('Number of quotes',fontsize = 16)
plt.xlim([-0.005,1])
plt.title('Sentimental probability distributions for gender inequality', fontsize = 16)
plt.grid()
ax.set_yscale('log')

# this controls where you put the legend with bbox_to_anchor
plt.figlegend(ncol = 1,loc = 1, fontsize = 16, bbox_to_anchor=(0.4, 0.4, 0.5, 0.5))

# this controls the grid labels size
plt.tick_params(axis='both', which='major', labelsize=16)

# this makes the plot tight
plt.tight_layout()


None

# %%
# Plotting the Compound Scores

mpl.style.use('seaborn-deep')

fig = plt.figure(figsize=(7,4))

ax = fig.add_subplot(1, 1, 1)

plt.hist(gw_sent['compound scores'], bins = 70, alpha=0.8)
plt.xlabel('Compound score',fontsize = 16)
plt.ylabel('Number of quotes',fontsize = 16)
plt.xlim([-1.005,1.005])
plt.title('Distribution of compound score values for gender inequality', fontsize = 16)
plt.grid()
ax.set_yscale('log')

# this controls the grid labels size
plt.tick_params(axis='both', which='major', labelsize=16)

# this makes the plot tight
plt.tight_layout()

None

# %%
positive=gi_sent[gi_sent['compound scores']>=0.05]
negative=gi_sent[gi_sent['compound scores']<=-0.05]
neutral=gi_sent[np.abs(gi_sent['compound scores'])< 0.05]

# %%
neutral.describe()
# Out:
#        positive scores  negative scores  compound scores
# count      5866.000000      5866.000000      5866.000000
# mean          0.011061         0.010896        -0.000063
# std           0.037339         0.036486         0.008252
# min           0.000000         0.000000        -0.049800
# 25%           0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000
# 75%           0.000000         0.000000         0.000000
# max           0.321000         0.347000         0.049800

# %%
positive.describe()
# Out:
#        positive scores  negative scores  compound scores
# count     12594.000000     12594.000000     12594.000000
# mean          0.172278         0.035152         0.539809
# std           0.095089         0.047189         0.257657
# min           0.018000         0.000000         0.050000
# 25%           0.104000         0.000000         0.340000
# 50%           0.153000         0.000000         0.540950
# 75%           0.219000         0.062000         0.764400
# max           0.835000         0.360000         0.997700

# %%
negative.describe()
# Out:
#        positive scores  negative scores  compound scores
# count     12805.000000     12805.000000     12805.000000
# mean          0.042013         0.208127        -0.545223
# std           0.053827         0.123236         0.262920
# min           0.000000         0.017000        -0.997600
# 25%           0.000000         0.120000        -0.771300
# 50%           0.000000         0.180000        -0.571900
# 75%           0.077000         0.264000        -0.339200
# max           0.412000         0.858000        -0.050200

# %%
# print total number of positive, negative and neutral quotes
print('Number of positive sent: ', positive.shape[0], '(', positive.shape[0]*100/gi_sent.shape[0],'%)')
print('Number of negative sent: ', negative.shape[0], '(', negative.shape[0]*100/gi_sent.shape[0],'%)')
print('Number of neutral sent: ', neutral.shape[0], '(', neutral.shape[0]*100/gi_sent.shape[0],'%)')
# Out:
# Number of positive sent:  12594 ( 40.28146489684951 %)
# Number of negative sent:  12805 ( 40.95634095634096 %)
# Number of neutral sent:  5866 ( 18.76219414680953 %)

# %% [markdown]
# ### Gun Control

# %%
gc_sent.head()
# Out:
#                       quoteID  \
# Unnamed: 0
# 408         2015-12-15-002818
# 3089        2015-02-20-038705
# 7977        2015-09-19-042453
# 8264        2015-10-13-054087
# 11789       2015-04-19-040043
#
#                                                     quotation       speaker  \
# Unnamed: 0
# 408         a vitriolic attack on the twin pillars of Amer...          None
# 3089        I'm in favor of students who have their concea...    Cary Smith
# 7977        scary sounding phrases like `assault weapons,'...  Donald Trump
# 8264        It is a constitutionally-protected right, like...   Wendy Davis
# 11789       This country, and especially the State of Texa...          None
#
#                                                          qids  \
# Unnamed: 0
# 408                                                        []
# 3089                                 ['Q5047652', 'Q5047654']
# 7977                                  ['Q22686', 'Q27947481']
# 8264        ['Q3539529', 'Q47358063', 'Q59160484', 'Q79826...
# 11789                                                      []
#
#                            date  \
# Unnamed: 0
# 408         2015-12-15 07:34:41
# 3089        2015-02-20 00:51:00
# 7977        2015-09-19 05:27:02
# 8264        2015-10-13 23:31:37
# 11789       2015-04-19 16:50:49
#
#                                                        probas  \
# Unnamed: 0
# 408           [['None', '0.5739'], ['Dana Loesch', '0.4261']]
# 3089        [['Cary Smith', '0.7423'], ['None', '0.1626'],...
# 7977         [['Donald Trump', '0.7814'], ['None', '0.2186']]
# 8264        [['Wendy Davis', '0.7397'], ['None', '0.2302']...
# 11789       [['None', '0.6643'], ['President Obama', '0.26...
#
#             positive scores  negative scores  compound scores  year
# Unnamed: 0
# 408                   0.188            0.277          -0.2500  2015
# 3089                  0.192            0.000           0.6124  2015
# 7977                  0.095            0.561          -0.9042  2015
# 8264                  0.098            0.000           0.3612  2015
# 11789                 0.117            0.161          -0.4449  2015

# %%
# Plotting Positive and Negative Probability Distributions
mpl.style.use('seaborn-deep')

fig = plt.figure(figsize=(7,4))

ax = fig.add_subplot(1, 1, 1)

plt.hist(gi_sent['positive scores'],label='positive', bins = 50, alpha=0.9)
plt.hist(gi_sent['negative scores'],label='negative', bins = 50, alpha=0.6)
plt.xlabel('Probability',fontsize = 16)
plt.ylabel('Number of quotes',fontsize = 16)
plt.xlim([-0.005,1])
plt.title('Sentimental probability distributions for gun control', fontsize = 16)
plt.grid()
ax.set_yscale('log')

# this controls where you put the legend with bbox_to_anchor
plt.figlegend(ncol = 1,loc = 1, fontsize = 16, bbox_to_anchor=(0.4, 0.4, 0.5, 0.5))

# this controls the grid labels size
plt.tick_params(axis='both', which='major', labelsize=16)

# this makes the plot tight
plt.tight_layout()


None

# %%
# Plotting the Compound Scores



fig = plt.figure(figsize=(7,4))

ax = fig.add_subplot(1, 1, 1)

plt.hist(gw_sent['compound scores'], bins = 70, alpha=0.8)
plt.xlabel('Compound score',fontsize = 16)
plt.ylabel('Number of quotes',fontsize = 16)
plt.xlim([-1.005,1.005])
plt.title('Distribution of compound score values for gun control', fontsize = 16)
plt.grid()
ax.set_yscale('log')

# this controls the grid labels size
plt.tick_params(axis='both', which='major', labelsize=16)

# this makes the plot tight
plt.tight_layout()

None

# %%
positive=gc_sent[gc_sent['compound scores']>=0.05]
negative=gc_sent[gc_sent['compound scores']<=-0.05]
neutral=gc_sent[np.abs(gc_sent['compound scores'])< 0.05]

# %%
neutral.describe()
# Out:
#        positive scores  negative scores  compound scores
# count      1217.000000      1217.000000      1217.000000
# mean          0.030783         0.030336         0.000297
# std           0.059127         0.058738         0.013064
# min           0.000000         0.000000        -0.049800
# 25%           0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000
# 75%           0.040000         0.034000         0.000000
# max           0.316000         0.312000         0.049800

# %%
positive.describe()
# Out:
#        positive scores  negative scores  compound scores
# count      3945.000000      3945.000000      3945.000000
# mean          0.190453         0.053444         0.496387
# std           0.092327         0.061805         0.256359
# min           0.020000         0.000000         0.050000
# 25%           0.123000         0.000000         0.294400
# 50%           0.174000         0.039000         0.492700
# 75%           0.241000         0.093000         0.709600
# max           0.636000         0.329000         0.994400

# %%
negative.describe()
# Out:
#        positive scores  negative scores  compound scores
# count      6150.000000      6150.000000      6150.000000
# mean          0.048874         0.233235        -0.577751
# std           0.057175         0.126280         0.256335
# min           0.000000         0.020000        -0.998700
# 25%           0.000000         0.142000        -0.810725
# 50%           0.032000         0.208000        -0.585900
# 75%           0.086000         0.294000        -0.340000
# max           0.342000         0.906000        -0.050500

# %%
# print total number of positive, negative and neutral quotes
print('Number of positive sent: ', positive.shape[0], '(', positive.shape[0]*100/gc_sent.shape[0],'%)')
print('Number of negative sent: ', negative.shape[0], '(', negative.shape[0]*100/gc_sent.shape[0],'%)')
print('Number of neutral sent: ', neutral.shape[0], '(', neutral.shape[0]*100/gc_sent.shape[0],'%)')
# Out:
# Number of positive sent:  3945 ( 34.87446958981612 %)
# Number of negative sent:  6150 ( 54.36704384724187 %)
# Number of neutral sent:  1217 ( 10.758486562942009 %)

# %% [markdown]
# ## Analysis over the years

# %% [markdown]
# ### Global warming

# %%
fig, axs = plt.subplots(6,figsize=(20,20), sharex=True)
for i in range(6):
    s=str(2015+i)
    axs[i].hist(gw_sent[gw_sent['year']==s]['compound scores'],bins=70, alpha = 1, color = 'C'+str(i))
    axs[i].grid()
    axs[i].set_yscale('log')
    axs[i].title.set_text('Year '+ s)
    axs[i].set_xlim([-1.005,1.005])
    axs[i].tick_params(axis='both', which='major', labelsize=16)
    # this makes the plot tight
    fig.tight_layout()
    
    
# Setting xlabel, ylabel
fig.text(0.5, -0.02, 'Compound Score', ha='center', fontsize=30)
fig.text(-0.02, 0.5, 'Number of Quotes', va='center', rotation='vertical', fontsize=30)
fig.suptitle('Distribution of Compound Score Over the Years', fontsize = 30, x=0.5, y=1.02)
None

# %%
gw_sent.groupby('year').count()
# Out:
#       quoteID  quotation  speaker   qids   date  probas  positive scores  \
# year
# 2015    37901      37901    37901  37901  37901   37901            37901
# 2016    18773      18773    18773  18773  18773   18773            18773
# 2017    24328      24328    24328  24328  24328   24328            24328
# 2018    27929      27929    27929  27929  27929   27929            27929
# 2019    35820      35820    35820  35820  35820   35820            35820
# 2020    21614      21614    21614  21614  21614   21614            21614
#
#       negative scores  compound scores
# year
# 2015            37901            37901
# 2016            18773            18773
# 2017            24328            24328
# 2018            27929            27929
# 2019            35820            35820
# 2020            21614            21614
